# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
pd.set_option('display.max_column', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# #### Loading Dataset

# %%
path = os.path.join('..', 'Data', 'creditcard.csv')
data = pd.read_csv(path)

# %% [markdown]
# #### Sample Dataset

# %%
data.head()

# %% [markdown]
# #### Data description
# ##### Features:
# - V1 to V28 — these are PCA-transformed features. Kaggle anonymized the real data for privacy
# - Time — seconds elapsed between each transaction and the first transaction in the dataset
# - Amount — transaction amount in euros
# - Class — target variable. 1 = fraud, 0 = legit

# %% [markdown]
# #### Exploring Data

# %%
data.shape

# %%
data.info()

# %%
data.describe()

# %%
data.nunique()

# %% [markdown]
# #### Conclusion
#
# - No null values
# - rows n columns (284807, 31)
# -

# %% [markdown]
# #### Plotting Graphs

# %%
corr = data.corr()['Class'].drop('Class').sort_values()
corr.plot(kind='bar', figsize=(15,5))
plt.title('Feature Correlation with Fraud')
plt.show()

# %%
sns.histplot(data['Amount'], bins=50, kde=True)
plt.title('Transaction Amount Distribution')
plt.show()

# %%
sns.kdeplot(data[data['Class'] == 1]['Amount'], label = 'Fraud', shade = True)
sns.kdeplot(data[data['Class'] == 0]['Amount'], label = 'Legit', shade = True)
plt.title('Amount Distribution: Fraud v/s Legit')
plt.legend()
plt.show()

# %%
sns.kdeplot(data[data['Class'] == 1]['Time'], label = 'Fraud', shade = True)
sns.kdeplot(data[data['Class'] == 0]['Time'], label = 'Legit', shade = True)
plt.title('Time Distribution: Fraud v/s Legit')
plt.legend()
plt.show()
